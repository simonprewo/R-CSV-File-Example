# %% [markdown]
# # Einlesen der Daten
# Schau Dir zunächst die CSV-Datei *salary.csv* im Verzeichnis *data* an. [Hier findest Du sie.](https://raw.githubusercontent.com/simonprewo/R-CSV-File-Example/master/data/salary.csv)
# Wir beginnen mit Einlesen der Daten per CSV:

# %%
mitarbeiter = read.csv("data/mitarbeiter.csv")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file 'data/mitarbeiter.csv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("data/mitarbeiter.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %% [markdown]
# # Anzeigen der Daten

# %%
print(mitarbeiter)
# Out:
#      Name   Bereich Jahresgehalt
# 1  Daniel        IT        41000
# 2   Maria Marketing        45000
# 3    Mark        IT        62000
# 4  Dieter Marketing        50000
# 5 Martina        IT        35000

# %% [markdown]
# # Durchschnittsgehalt berechnen

# %%
durchschnittsgehalt = mean(mitarbeiter$Jahresgehalt)
# Out:
# Error in mean(mitarbeiter$Jahresgehalt): object 'mitarbeiter' not found
# Traceback:
#
# 1. mean(mitarbeiter$Jahresgehalt)

# %%
print(durchschnittsgehalt)
